# %% [markdown]
# # Tensor boolean Masking

# %% [markdown]
# ## import required pkg

# %%
import numpy as np
import torch

# %% [markdown]
# ## create a tensor

# %%
vector = torch.tensor([10,20,30,40,50,60])

# %%
vector
# Out:
# tensor([10, 20, 30, 40, 50, 60])

# %% [markdown]
# ## boolean Indexing

# %%
# [10,20, 30]

vector[[True, False, True, True, False, False]]
# Out:
# tensor([10, 30, 40])

# %% [markdown]
# ## filtering the tensor

# %%
# broadcasting
vector > 30
# Out:
# tensor([False, False, False,  True,  True,  True])

# %%
vector[vector > 30]
# Out:
# tensor([40, 50, 60])
