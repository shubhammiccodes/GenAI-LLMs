# %% [markdown]
# # Tensor  reducing operations

# %% [markdown]
# ## import required pkg

# %%
import numpy as np
import torch

# %% [markdown]
# ## create rank1 tensor

# %%
vector = torch.tensor([10, 20, 30, 40, 50, 60], dtype = torch.float32)
vector
# Out:
# tensor([10., 20., 30., 40., 50., 60.])

# %% [markdown]
# ## perform reducing (aggregation) operation

# %%
print(f"max val = {vector.max()}")
# Out:
# max val = 60.0

# %%
print(f"min val = {vector.min()}")
# Out:
# min val = 10.0

# %%
print(f"mean val = {vector.mean()}")
# Out:
# mean val = 35.0

# %%
print(f"sum of all val = {vector.sum()}")
# Out:
# sum of all val = 210.0

# %%
print(f"product of all val = {vector.prod()}")
# Out:
# product of all val = 720000000.0

# %%
print(f"standard deviation = {vector.std()}")
# Out:
# standard deviation = 18.70828628540039

# %% [markdown]
# ## create rank 2 tensor

# %%
matrix =  torch.tensor([[10, 20, 30], [40, 50, 60]], dtype = torch.float32)
matrix
# Out:
# tensor([[10., 20., 30.],
#         [40., 50., 60.]])

# %% [markdown]
# ## perform reducing oper.

# %%
print(f"max value = {matrix.max()}")
# Out:
# max value = 60.0

# %%
print(f"min value = {matrix.min()}")
# Out:
# min value = 10.0

# %%
print(f"mean value = {matrix.mean()}")
# Out:
# mean value = 35.0

# %%
print(f"sum of all the values = {matrix.sum()}")
# Out:
# sum of all the values = 210.0

# %%
print(f"product of all the vlaues = {matrix.prod()}")
# Out:
# product of all the vlaues = 720000000.0

# %%
print(f"standard deviation = {matrix.std()}")
# Out:
# standard deviation = 18.70828628540039

# %% [markdown]
# ### *perform oper. columnwise

# %%
# dim = 0 : column
print(f"max val = {matrix.max(dim = 0).values}")
# Out:
# max val = tensor([40., 50., 60.])

# %%
print(f"min val = {matrix.min(dim = 0).values}")
# Out:
# min val = tensor([10., 20., 30.])

# %%
print(f"mean val = {matrix.mean(dim = 0)}")
# Out:
# mean val = tensor([25., 35., 45.])

# %%
print(f"sum of all values = {matrix.sum(dim =0)}")
# Out:
# sum of all values = tensor([50., 70., 90.])

# %% [markdown]
# ### * perform oper. Row wise

# %%
# dim = 1: row
print(f"max value = {matrix.max(dim=1).values}")
# Out:
# max value = tensor([30., 60.])

# %%
print(f"min value = {matrix.min(dim=1).values}")
# Out:
# min value = tensor([10., 40.])

# %%
print(f"mean value = {matrix.mean(dim=1)}")
# Out:
# mean value = tensor([20., 50.])

# %%
print(f"sum of all the values = {matrix.sum(dim=1)}")
# Out:
# sum of all the values = tensor([ 60., 150.])

# %%
matrix.max(dim = 0)
# Out:
# torch.return_types.max(
# values=tensor([40., 50., 60.]),
# indices=tensor([1, 1, 1]))

# %%
matrix.min(dim = 1)
# Out:
# torch.return_types.min(
# values=tensor([10., 40.]),
# indices=tensor([0, 0]))

# %%
matrix.mean(dim = 1)
# Out:
# tensor([20., 50.])
